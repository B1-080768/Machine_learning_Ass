# %%
# Que. 3You own an ice cream business and you would like to create a model that could predict the daily revenue in dollars based on the outside air temperature (degC). Build Linear Regression Model and evaluate it with measuring different errors.
# Dataset : IceCreamData.csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
df = pd.read_csv('IceCreamData.csv')
df.head(3)
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289

# %%
X = df.drop('Revenue',axis = 1)
Y = df[['Revenue']]
model = LinearRegression()
model.fit(X,Y)
plt.scatter(df['Temperature'],df['Revenue'])
y_predict = model.predict(X)
plt.plot(df['Temperature'],y_predict,c = "red",label = "regression line")
plt.scatter(df['Temperature'],y_predict , c = "red")
plt.xlabel("Temperature")
plt.ylabel('Revenue')
plt.title("revenue depending upon temperature")
plt.show()

# %%
####  create the new_model and evaluate it
x_train,x_test,y_train,y_test =train_test_split(X,Y,test_size = 0.7,random_state = 12345)
model = LinearRegression()
model.fit(x_train,y_train)
y_true = y_test
y_true
y_pred = model.predict(x_test)
mae = mean_absolute_error(y_true,y_pred)
mse = mean_squared_error(y_true,y_pred)

rmse  = np.sqrt(mse)
y_predict
# rmse
print(f"mae ={mae:.2f},mse = {mse:.2f},rmse = {rmse:.2f},r2  ={r2:.2f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 10
#       8 mae = mean_absolute_error(y_true,y_pred)
#       9 mse = mean_squared_error(y_true,y_pred)
# ---> 10 r2_score = r2_score(y_true,y_pred)
#      11 rmse  = np.sqrt(mse)
#      12 y_predict
#
# TypeError: 'numpy.float64' object is not callable

# %%
r2_score = r2_score(y_true,y_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 r2_score = r2_score(y_true,y_pred)
#
# TypeError: 'numpy.float64' object is not callable

# %%
from sklearn.model_selection import train_test_split ### split the data 
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.7,random_state = 12345)
model = LinearRegression() ## model creation
model.fit(x_train,y_train)
y_true = y_test
y_pred = model.predict(x_test)
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae = mean_absolute_error(y_true,y_pred)
mae
mse = mean_squared_error(y_true,y_pred)
mse
rmse = np.sqrt(mse)
rmse
r2_score = r2_score(y_true,y_pred)
r2_score
print(f"mae ={mae:.2f},mse = {mse:.2f},rmse = {rmse:.2f},r2_score = {r2_score:.2f}")
# Out:
# mae =20.61,mse = 677.29,rmse = 26.02,r2_score = 0.98
