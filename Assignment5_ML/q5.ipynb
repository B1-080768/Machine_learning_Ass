# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
df = pd.read_csv("Grocery_std.csv")
df.drop(['Unnamed: 0'],axis = 1,inplace = True)
df.columns
# Out:
# Index(['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen'], dtype='object')

# %%
df1 = df[['Fresh', 'Milk', 'Frozen', 'Detergents_Paper', 'Delicassen']]

# %%
pca = PCA(n_components = 1)
pca.fit(df1)
p1 = pca.transform(df1)
p2 = pd.DataFrame(p1)
p2.columns= ['pc1']
p2
df = pd.concat([df,p2],axis = 1)
df
# Out:
#         Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicassen  \
# 0    0.052933  0.523568 -0.041115 -0.589367         -0.043569   -0.066339
# 1   -0.391302  0.544458  0.170318 -0.270136          0.086407    0.089151
# 2   -0.447029  0.408538 -0.028157 -0.137536          0.133232    2.243293
# 3    0.100111 -0.624020 -0.392977  0.687144         -0.498588    0.093411
# 4    0.840239 -0.052396 -0.079356  0.173859         -0.231918    1.299347
# ..        ...       ...       ...       ...               ...         ...
# 435  1.401312  0.848446  0.850760  2.075222         -0.566831    0.241091
# 436  2.155293 -0.592142 -0.757165  0.296561         -0.585519    0.291501
# 437  0.200326  1.314671  2.348386 -0.543380          2.511218    0.121456
# 438 -0.135384 -0.517536 -0.602514 -0.419441         -0.569770    0.213046
# 439 -0.729307 -0.555924 -0.573227 -0.620094         -0.504888   -0.522869
#
#           pc1
# 0    0.059955
# 1    0.186702
# 2    1.292776
# 3   -0.230899
# ...

# %%
from sklearn.cluster import AgglomerativeClustering
ac  = AgglomerativeClustering(n_clusters = 2)
plt.figure(figsize = (6,6))
plt.scatter(df['Grocery'],df['pc1'],c = ac.fit_predict(df),cmap = 'rainbow')
plt.xlabel('Grocery')
plt.ylabel('pc1')
plt.title('visualization of grocery data ')
plt.show()
